# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("INTCtechnicals.csv")

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'INTC_Unnamed: 0',
#  'INTC_time',
#  'INTC_open',
#  'INTC_high',
#  'INTC_low',
#  'INTC_close',
#  'INTC_volume',
#  'INTC_volume_adi',
#  'INTC_volume_obv',
#  'INTC_volume_cmf',
#  'INTC_volume_fi',
#  'INTC_momentum_mfi',
#  'INTC_volume_em',
#  'INTC_volume_sma_em',
#  'INTC_volume_vpt',
#  'INTC_volume_nvi',
#  'INTC_volume_vwap',
#  'INTC_volatility_atr',
#  'INTC_volatility_bbm',
#  'INTC_volatility_bbh',
#  'INTC_volatility_bbl',
#  'INTC_volatility_bbw',
#  'INTC_volatility_bbp',
#  'INTC_volatility_bbhi',
#  'INTC_volatility_bbli',
#  'INTC_volatility_kcc',
#  'INTC_volatility_kch',
#  'INTC_volatility_kcl',
#  'INTC_volatility_kcw',
#  'INTC_volatility_kcp',
#  'INTC_volatility_kchi',
#  'INTC_volatility_kcli',
#  'INTC_volatility_dcl',
#  'INTC_volatility_dch',
#  'INTC_trend_macd',
#  'INTC_trend_macd_signal',
#  'INTC_trend_macd_diff',
#  'INTC_trend_sma_fast',
#  'INTC_trend_sma_slow',
#  'INTC_trend_ema_fast',
#  'INTC_trend_ema_slow',
#  'INTC_trend_adx',
#  'INTC_trend_adx_pos',
#  'INTC_trend_adx_neg',
#  'INTC_trend_vortex_ind_pos',
#  'INTC_trend_vortex_ind_neg',
#  'INTC_trend_vortex_ind_diff',
#  'INTC_trend_trix',
#  'INTC_trend_mass_index',
#  'INTC_trend_cci',
#  'INTC_trend_dpo',
#  'INTC_trend_kst',
#  'INTC_trend_kst_sig',
#  'INTC_trend_kst_diff',
#  'INTC_trend_ichimoku_conv',
#  'INTC_trend_ichimoku_base',
#  'INTC_trend_ichimoku_a',
#  'INTC_trend_ichimoku_b',
#  'INTC_trend_visual_ichimoku_a',
#  'INTC_trend_visual_ichimoku_b',
#  'INTC_trend_aroon_up',
#  'INTC_trend_aroon_down',
#  'INTC_trend_aroon_ind',
#  'INTC_trend_psar_up',
#  'INTC_trend_psar_down',
#  'INTC_trend_psar_up_indicator',
#  'INTC_trend_psar_down_indicator',
#  'INTC_momentum_rsi',
#  'INTC_momentum_tsi',
#  'INTC_momentum_uo',
#  'INTC_momentum_stoch',
#  'INTC_momentum_stoch_signal',
#  'INTC_momentum_wr',
#  'INTC_momentum_ao',
#  'INTC_momentum_kama',
#  'INTC_momentum_roc',
#  'INTC_others_dr',
#  'INTC_others_dlr',
#  'INTC_others_cr']

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
Y = data["INTC_close"]
X = data.drop(['Unnamed: 0',"INTC_time",
 'INTC_Unnamed: 0',"INTC_close","INTC_momentum_kama"], axis=1)

# %%
# Lagging the Y by 1 time step
# Predicting one step ahead
Y= Y[31:]
X= X[30:-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=60)

# %%
X_train
# Out:
#         INTC_open  INTC_high   INTC_low  INTC_volume  INTC_volume_adi  \
# 216152  53.018666  53.026332  53.016750         5550    -7.821231e+07
# 131960  56.472972  56.472972  56.443696        88951    -5.238368e+07
# 147109  54.709988  54.714841  54.690577        29257    -5.259521e+07
# 31864   50.237079  50.266864  50.227151        13778    -1.482103e+07
# 190316  45.639764  45.649405  45.639764         3426    -6.728103e+07
# ...           ...        ...        ...          ...              ...
# 6573    43.962408  43.962408  43.962408         1323    -2.911526e+06
# 247208  44.433526  44.476374  44.419243        42826    -8.102823e+07
# 241252  46.723521  46.756847  46.718760        44343    -7.497410e+07
# 232543  48.359938  48.379102  48.359938        20664    -8.564036e+07
# 133355  55.262906  55.272665  55.233631        29301    -5.212556e+07
#
#         INTC_volume_obv  INTC_volume_cmf  INTC_volume_fi  INTC_momentum_mfi  \
# 216152        642130592         0.316714      -43.229546          34.627825
# 131960        336461093        -0.136857      806.985023          82.594766
# 147109        386806736        -0.059225      -60.939065          34.681123
# 31864          95114883        -0.146728      -21.909937          54.819751
# 190316        553273369        -0.376290       13.370176          51.629465
# ...                 ...              ...             ...                ...
# 6573           12800347        -0.344780        3.266843          77.695975
# 247208        747778898         0.185492     -651.351477          21.662301
# 241252        727711302         0.099669     -200.310784          17.380847
# 232543        689183568        -0.131790      137.079471          70.331390
# 133355        337511685        -0.067275      127.127814          66.984830
#
#         INTC_volume_em  ...  INTC_momentum_tsi  INTC_momentum_uo  \
# 216152        0.827145  ...         -22.684694         53.160810
# 131960        0.481766  ...         -13.746417         44.780552
# 147109       -1.146997  ...         -17.397461         40.558242
# 31864        -0.715421  ...          -8.464776         52.168786
# 190316        3.391196  ...          32.389088         52.754535
# ...                ...  ...                ...               ...
# 6573         -0.000000  ...          -7.240794         27.995675
# 247208       -2.540462  ...         -34.171489         47.485677
# 241252       -0.817851  ...          -9.982889         53.192751
# 232543        0.888629  ...          12.245140         39.998604
# 133355       -3.575070  ...          13.654990         52.392560
#
#         INTC_momentum_stoch  INTC_momentum_stoch_signal  INTC_momentum_wr  \
# 216152            27.272727                   30.909091        -72.727273
# 131960            73.170732                   69.105691        -26.829268
# 147109             9.090909                    8.030303        -90.909091
# 31864             34.782609                   20.956522        -65.217391
# 190316            93.000000                   73.361111         -7.000000
# ...                     ...                         ...               ...
# 6573               5.068638                    6.241934        -94.931362
# 247208             6.451613                   10.709815        -93.548387
# 241252            29.411765                   18.970588        -70.588235
# 232543            94.736842                   81.578947         -5.263158
# 133355            73.333333                   76.323529        -26.666667
#
#         INTC_momentum_ao  INTC_momentum_roc  INTC_others_dr  INTC_others_dlr  \
# 216152         -0.053587          -0.144378       -0.036134        -0.036140
# 131960         -0.061476           0.103824        0.017289         0.017288
# 147109         -0.022918          -0.177117       -0.017740        -0.017742
# 31864          -0.043102          -0.069095        0.044864         0.044854
# 190316          0.048229           0.075671        0.043951         0.043942
# ...                  ...                ...             ...              ...
# 6573           -0.029264          -0.135318       -0.022578        -0.022581
# 247208         -0.172951          -0.469183       -0.085635        -0.085671
# 241252         -0.050894          -0.051918        0.000000         0.000000
# 232543          0.039604           0.148780        0.049544         0.049532
# 133355          0.049258           0.031613        0.000000         0.000000
#
#         INTC_others_cr
# 216152       14.556503
# 131960       21.982400
# 147109       18.194214
# 31864         8.593205
# 190316       -1.371315
# ...                ...
# 6573         -5.007761
# 247208       -3.979501
# 241252        0.999492
# 232543        4.525304
# 133355       19.430996
#
# [155402 rows x 75 columns]

# %%
X_train = X_train.dropna(axis =1)

# %%
X_test = X_test.dropna(axis =1)

# %%
X_test
# Out:
#         INTC_open  INTC_high   INTC_low  INTC_volume  INTC_volume_adi  \
# 117231  64.104191  64.192018  64.104191        49395    -4.697084e+07
# 53750   58.290001  58.290001  58.280140          360    -3.353471e+07
# 182844  47.938334  47.953567  47.938334        18416    -6.289837e+07
# 230825  49.164819  49.174401  49.147667        43775    -8.644723e+07
# 82377   59.859439  59.859439  59.692727        76435    -3.086038e+07
# ...           ...        ...        ...          ...              ...
# 113246  66.047399  66.096432  66.047399        28530    -4.473840e+07
# 226132  50.947055  50.966219  50.937473        27841    -8.817677e+07
# 62405   59.157794  59.216961  59.157794        57607    -3.012910e+07
# 142217  57.292694  57.321969  57.282935        25541    -5.415794e+07
# 178644  50.387880  50.402342  50.373419        14038    -7.044587e+07
#
#         INTC_volume_obv  INTC_volume_cmf  INTC_volume_fi  INTC_volume_em  \
# 117231        322938974         0.095071      -63.878276       -4.337843
# 53750         193070949         0.047396      418.483426       13.506217
# 182844        516701757         0.075681      -18.809027       -0.629969
# 230825        679915233        -0.278830      -39.953364        0.939200
# 82377         260165502         0.207999     1510.692611        7.486191
# ...                 ...              ...             ...             ...
# 113246        324560275         0.199616     -104.804128       -2.528109
# 226132        659924678        -0.244260       30.418029        0.989330
# 62405         221380289        -0.200145     -496.112742       -0.506422
# 142217        372592005        -0.336179       37.091819        1.864260
# 178644        509436713        -0.025569      320.023091       -0.993153
#
#         INTC_volume_vpt  ...  INTC_trend_aroon_up  INTC_trend_aroon_down  \
# 117231         7.561136  ...                 28.0                   80.0
# 53750          0.000000  ...                  8.0                   80.0
# 182844        11.118908  ...                  4.0                   92.0
# 230825       -12.638178  ...                 52.0                   28.0
# 82377        -24.529652  ...                 88.0                   44.0
# ...                 ...  ...                  ...                    ...
# 113246        10.730796  ...                  4.0                   72.0
# 226132         6.603437  ...                 60.0                   16.0
# 62405        -42.415306  ...                  4.0                  100.0
# 142217        10.014955  ...                  4.0                   56.0
# 178644        13.552245  ...                100.0                   56.0
#
#         INTC_trend_aroon_ind  INTC_trend_psar_up_indicator  \
# 117231                 -52.0                           0.0
# 53750                  -72.0                           0.0
# 182844                 -88.0                           0.0
# 230825                  24.0                           0.0
# 82377                   44.0                           0.0
# ...                      ...                           ...
# 113246                 -68.0                           0.0
# 226132                  44.0                           0.0
# 62405                  -96.0                           0.0
# 142217                 -52.0                           0.0
# 178644                  44.0                           0.0
#
#         INTC_trend_psar_down_indicator  INTC_momentum_rsi  INTC_momentum_roc  \
# 117231                             0.0          45.517059          -0.151791
# 53750                              0.0          35.726136          -0.337268
# 182844                             0.0          38.230808          -0.070323
# 230825                             0.0          53.812290          -0.058445
# 82377                              0.0          44.534546          -0.090201
# ...                                ...                ...                ...
# 113246                             0.0          45.256354          -0.081412
# 226132                             0.0          56.437263           0.056444
# 62405                              0.0          39.488331          -0.158070
# 142217                             0.0          59.230463           0.143612
# 178644                             0.0          64.623987           0.153257
#
#         INTC_others_dr  INTC_others_dlr  INTC_others_cr
# 117231       -0.007601        -0.007601       38.703583
# 53750         0.000000         0.000000       25.929430
# 182844       -0.008645        -0.008645        3.605761
# 230825        0.039002         0.038994        6.212698
# 82377         0.032841         0.032835       29.087640
# ...                ...              ...             ...
# 113246       -0.014691        -0.014692       42.776397
# 226132        0.037622         0.037615       10.105094
# 62405        -0.058461        -0.058478       27.857791
# 142217        0.031689         0.031684       23.804650
# 178644        0.028700         0.028696        8.907393
#
# [103602 rows x 56 columns]

# %%
correlation_row = data.corr()[5:6]

# %%
high_corr_list = []
for i in range(len(list(correlation_row.T["INTC_close"]))):
    if list(correlation_row.T["INTC_close"])[i] > 0.5 or list(correlation_row.T["INTC_close"])[i] < -0.5:
        high_corr_list.append(list(correlation_row)[i])
        print (f'{list(correlation_row)[i]} has a correlation with closing price of {list(correlation_row.T["INTC_close"])[i]}')
# Out:
# INTC_open has a correlation with closing price of 0.9999583657320795
# INTC_high has a correlation with closing price of 0.9999582856587971
# INTC_low has a correlation with closing price of 0.9999718449990844
# INTC_close has a correlation with closing price of 1.0
# INTC_volume_vwap has a correlation with closing price of 0.9997723439429931
# INTC_volatility_bbm has a correlation with closing price of 0.9996957225305354
# INTC_volatility_bbh has a correlation with closing price of 0.9993448010926343
# INTC_volatility_bbl has a correlation with closing price of 0.9992869135335869
# INTC_volatility_kcc has a correlation with closing price of 0.9998641247372565
# INTC_volatility_kch has a correlation with closing price of 0.9998308105958732
# INTC_volatility_kcl has a correlation with closing price of 0.9998249963744729
# INTC_trend_sma_fast has a correlation with closing price of 0.9998216552347884
# INTC_trend_sma_slow has a correlation with closing price of 0.9996009563694176
# INTC_trend_ema_fast has a correlation with closing price of 0.9998710973800956
# INTC_trend_ema_slow has a correlation with closing price of 0.9997055214195079
# INTC_trend_ichimoku_conv has a correlation with closing price of 0.9998573864619761
# INTC_trend_ichimoku_base has a correlation with closing price of 0.999587200371025
# INTC_trend_ichimoku_a has a correlation with closing price of 0.9997783026505012
# INTC_trend_ichimoku_b has a correlation with closing price of 0.9992044925030857
# INTC_trend_visual_ichimoku_a has a correlation with closing price of 0.9985896488131693
# INTC_trend_visual_ichimoku_b has a correlation with closing price of 0.9980936081396576
# INTC_trend_psar_up has a correlation with closing price of 0.9995914412205812
# INTC_trend_psar_down has a correlation with closing price of 0.9995176284898856
# INTC_momentum_kama has a correlation with closing price of 0.9996420362622617
# INTC_others_cr has a correlation with closing price of 0.999999999999954

# %%
high_corr_list
# Out:
# ['INTC_open',
#  'INTC_high',
#  'INTC_low',
#  'INTC_close',
#  'INTC_volume_vwap',
#  'INTC_volatility_bbm',
#  'INTC_volatility_bbh',
#  'INTC_volatility_bbl',
#  'INTC_volatility_kcc',
#  'INTC_volatility_kch',
#  'INTC_volatility_kcl',
#  'INTC_trend_sma_fast',
#  'INTC_trend_sma_slow',
#  'INTC_trend_ema_fast',
#  'INTC_trend_ema_slow',
#  'INTC_trend_ichimoku_conv',
#  'INTC_trend_ichimoku_base',
#  'INTC_trend_ichimoku_a',
#  'INTC_trend_ichimoku_b',
#  'INTC_trend_visual_ichimoku_a',
#  'INTC_trend_visual_ichimoku_b',
#  'INTC_trend_psar_up',
#  'INTC_trend_psar_down',
#  'INTC_momentum_kama',
#  'INTC_others_cr']

# %%
# Drop Close 
high_corr_list.remove("INTC_close")

# %%
my_list = ['INTC_trend_psar_down', 'INTC_trend_visual_ichimoku_a', 'INTC_momentum_kama', 'INTC_trend_psar_up']
for i in my_list:
    high_corr_list.remove(i)

# %%
high_corr_list
# Out:
# ['INTC_open',
#  'INTC_high',
#  'INTC_low',
#  'INTC_volume_vwap',
#  'INTC_volatility_bbm',
#  'INTC_volatility_bbh',
#  'INTC_volatility_bbl',
#  'INTC_volatility_kcc',
#  'INTC_volatility_kch',
#  'INTC_volatility_kcl',
#  'INTC_trend_sma_fast',
#  'INTC_trend_sma_slow',
#  'INTC_trend_ema_fast',
#  'INTC_trend_ema_slow',
#  'INTC_trend_ichimoku_conv',
#  'INTC_trend_ichimoku_base',
#  'INTC_trend_ichimoku_a',
#  'INTC_trend_ichimoku_b',
#  'INTC_trend_visual_ichimoku_b',
#  'INTC_others_cr']

# %%
X_train3 = X_train[high_corr_list]
X_test3 = X_test[high_corr_list]

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(100,input_shape=(X_train3.shape[1],1)))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
X_train3 = np.array(X_train3).reshape((X_train3.shape[0],X_train3.shape[1],1))
X_test3 = np.array(X_test3).reshape((X_test3.shape[0],X_test3.shape[1],1))

# %%
history = model.fit(x=X_train3[:103606],y=Y_train[:103606],epochs=2,validation_data=(X_train3[103606:],Y_train[103606:]),shuffle=False)
# Out:
# Train on 103606 samples, validate on 51796 samples
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/2
# 103606/103606 [==============================] - 101s 973us/sample - loss: 97.1644 - val_loss: 0.1171
# Epoch 2/2
# 103606/103606 [==============================] - 113s 1ms/sample - loss: 0.0278 - val_loss: 0.0092

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 300

axes=plt.axes()
axes.plot(pd.DataFrame(model.history.history)['loss'], label='Loss')
axes.plot(pd.DataFrame(model.history.history)['val_loss'], label='Validation Loss')
axes.legend(loc=0)
axes.set_title('INTC Model fitting performance')
# Out:
# Text(0.5, 1.0, 'INTC Model fitting performance')

# %%
Y_predicted=model.predict(np.array(X_test3))
Y_true=np.array(Y_test).reshape(np.array(Y_test).shape[0],1)

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(Y_true[::100], label='True Y')
plt.plot(Y_predicted[::100], label='Predicted Y')
plt.legend(loc=0)
plt.title('INTC LSTM Prediction vs Actual')
plt.show()

# %%
from sklearn import metrics
Y_p=Y_predicted
Y_t=Y_true

print(f'The Model Accuracy (%) for INTC is {(1-(metrics.mean_absolute_error(Y_t, Y_p)/Y_t.mean()))*100}')

print('')
print('Prediction performance')
print(f'The MAE in % is {(metrics.mean_absolute_error(Y_true, Y_predicted)/Y_true.mean())*100}')
print(f'MSE: {metrics.mean_squared_error(Y_true, Y_predicted)}')
print(f'RMSE: {np.sqrt(metrics.mean_squared_error(Y_true, Y_predicted))}')
print(f'R2: {metrics.r2_score(Y_true, Y_predicted)}')
# Out:
# The Model Accuracy (%) for INTC is 99.87697641813841
#
# Prediction performance
# The MAE in % is 0.12302358186158824
# MSE: 0.008879861322878053
# RMSE: 0.09423301609774598
# R2: 0.9997428978945252

# %%
# Calculating the profits from the model

actual_y = list(Y)
predicted_y1 = model.predict(np.array(X_train3))
predicted_y2 = model.predict(np.array(X_test3))

# %%
predicted_y = [predicted_y1[i][0] for i in range(len(predicted_y1))] + [predicted_y2[i][0] for i in range(len(predicted_y2))]

# %%
starting_value = 1000000
portfolio_value = [starting_value]

# %%
stock_amount = portfolio_value[-1]/actual_y[0]

# %%
holding_period = 1

# %%
# 2.75 bsp transaction fees

def calculate_returns(holding_period, predicted_y, actual_y):
    starting_value = 1000000
    portfolio_value = [starting_value]
    
    for i in range(0,len(actual_y)-holding_period,holding_period):
        if predicted_y[i+holding_period] > actual_y[i]:
            
            #Buying if predicted price in the next time step is higher
            stock_amount = (portfolio_value[-1]*(1-0.000275))/actual_y[i]
            
            #Selling taking into account the transaction fees
            new_portfolio_value = (stock_amount*actual_y[i+holding_period])*(1-0.000275)
            portfolio_value.append(new_portfolio_value)
            
        elif predicted_y[i+holding_period] < actual_y[i]:
            
            #Selling first then buying back
            new_value_after_short = (- portfolio_value[-1]/actual_y[i] + portfolio_value[-1]/actual_y[i]*actual_y[i+holding_period])*(1-0.000275)**2
            portfolio_value.append(new_value_after_short)
        else:
            portfolio_value.append(portfolio_value[-1])
            
    return portfolio_value

# %%
holding_period_1 = calculate_returns(1, predicted_y, actual_y)

# %%
holding_period_5 = calculate_returns(5, predicted_y, actual_y)

# %%
holding_period_10 = calculate_returns(10, predicted_y, actual_y)

# %%
holding_period_1000 = calculate_returns(1000, predicted_y, actual_y)

# %%
holding_period_5000 = calculate_returns(5000, predicted_y, actual_y)

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(holding_period_1[:100], color='red', label= "holding for 1 minutes")
plt.plot(holding_period_5[:100], color='green', label= "holding for 5 minutes")
plt.plot(holding_period_10[:100], color='blue', label= "holding for 10 minutes")
plt.plot(holding_period_1000[:100], color='orange', label= "holding for 1000 minutes")
plt.plot(holding_period_5000[:100], color='pink', label= "holding for 5000 minutes")
plt.ylabel("Portfolio Value")
# Both Long and Short
plt.legend(loc=0)
plt.title('High Frequency Trading with LSTM Predictions: Different Holding Periods (INTC)\n')
plt.show()

# %%
# 2.75 bsp transaction fees, only execute if predicted is 20% higher

def calculate_returns2(holding_period, predicted_y, actual_y):
    starting_value = 1000000
    portfolio_value = [starting_value]
    
    for i in range(0,len(actual_y)-holding_period,holding_period):
        if predicted_y[i+holding_period] > 1.20*actual_y[i]:
            
            #Buying if predicted price in the next time step is higher
            stock_amount = (portfolio_value[-1]*(1-0.000275))/actual_y[i]
            
            #Selling taking into account the transaction fees
            new_portfolio_value = (stock_amount*actual_y[i+holding_period])*(1-0.000275)
            portfolio_value.append(new_portfolio_value)
            
        elif 1.20*predicted_y[i+holding_period] < actual_y[i]:
            
            #Selling first then buying back
            new_value_after_short = (- portfolio_value[-1]/actual_y[i] + portfolio_value[-1]/actual_y[i]*actual_y[i+holding_period])*(1-0.000275)**2
            portfolio_value.append(new_value_after_short)
            
        else:
            portfolio_value.append(portfolio_value[-1])
    return portfolio_value

# %%
holding_period_1_2 = calculate_returns2(1, predicted_y, actual_y)
holding_period_5_2 = calculate_returns2(5, predicted_y, actual_y)
holding_period_10_2 = calculate_returns2(10, predicted_y, actual_y)
holding_period_1000_2 = calculate_returns2(1000, predicted_y, actual_y)
holding_period_5000_2 = calculate_returns2(5000, predicted_y, actual_y)

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(holding_period_1_2[:100], color='red', label= "holding for 1 minutes")
plt.plot(holding_period_5_2[:100], color='green', label= "holding for 5 minutes")
plt.plot(holding_period_10_2[:100], color='blue', label= "holding for 10 minutes")
plt.plot(holding_period_1000_2[:100], color='orange', label= "holding for 1000 minutes")
plt.plot(holding_period_5000_2[:100], color='pink', label= "holding for 5000 minutes")

# Both Long and Short
plt.legend(loc=0)
plt.title('High Frequency Trading with LSTM Predictions: Only trading if predicted price is 20% higher\n')
plt.show()

# The index is not aligned because 5000 min frequency has to fit in with 1 min frequency, so I graphed it like this so everything can fit in one
