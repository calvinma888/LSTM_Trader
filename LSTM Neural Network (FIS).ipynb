# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("FIStechnicals.csv")

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'FIS_Unnamed: 0',
#  'FIS_time',
#  'FIS_open',
#  'FIS_high',
#  'FIS_low',
#  'FIS_close',
#  'FIS_volume',
#  'FIS_volume_adi',
#  'FIS_volume_obv',
#  'FIS_volume_cmf',
#  'FIS_volume_fi',
#  'FIS_momentum_mfi',
#  'FIS_volume_em',
#  'FIS_volume_sma_em',
#  'FIS_volume_vpt',
#  'FIS_volume_nvi',
#  'FIS_volume_vwap',
#  'FIS_volatility_atr',
#  'FIS_volatility_bbm',
#  'FIS_volatility_bbh',
#  'FIS_volatility_bbl',
#  'FIS_volatility_bbw',
#  'FIS_volatility_bbp',
#  'FIS_volatility_bbhi',
#  'FIS_volatility_bbli',
#  'FIS_volatility_kcc',
#  'FIS_volatility_kch',
#  'FIS_volatility_kcl',
#  'FIS_volatility_kcw',
#  'FIS_volatility_kcp',
#  'FIS_volatility_kchi',
#  'FIS_volatility_kcli',
#  'FIS_volatility_dcl',
#  'FIS_volatility_dch',
#  'FIS_trend_macd',
#  'FIS_trend_macd_signal',
#  'FIS_trend_macd_diff',
#  'FIS_trend_sma_fast',
#  'FIS_trend_sma_slow',
#  'FIS_trend_ema_fast',
#  'FIS_trend_ema_slow',
#  'FIS_trend_adx',
#  'FIS_trend_adx_pos',
#  'FIS_trend_adx_neg',
#  'FIS_trend_vortex_ind_pos',
#  'FIS_trend_vortex_ind_neg',
#  'FIS_trend_vortex_ind_diff',
#  'FIS_trend_trix',
#  'FIS_trend_mass_index',
#  'FIS_trend_cci',
#  'FIS_trend_dpo',
#  'FIS_trend_kst',
#  'FIS_trend_kst_sig',
#  'FIS_trend_kst_diff',
#  'FIS_trend_ichimoku_conv',
#  'FIS_trend_ichimoku_base',
#  'FIS_trend_ichimoku_a',
#  'FIS_trend_ichimoku_b',
#  'FIS_trend_visual_ichimoku_a',
#  'FIS_trend_visual_ichimoku_b',
#  'FIS_trend_aroon_up',
#  'FIS_trend_aroon_down',
#  'FIS_trend_aroon_ind',
#  'FIS_trend_psar_up',
#  'FIS_trend_psar_down',
#  'FIS_trend_psar_up_indicator',
#  'FIS_trend_psar_down_indicator',
#  'FIS_momentum_rsi',
#  'FIS_momentum_tsi',
#  'FIS_momentum_uo',
#  'FIS_momentum_stoch',
#  'FIS_momentum_stoch_signal',
#  'FIS_momentum_wr',
#  'FIS_momentum_ao',
#  'FIS_momentum_kama',
#  'FIS_momentum_roc',
#  'FIS_others_dr',
#  'FIS_others_dlr',
#  'FIS_others_cr']

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
Y = data["FIS_close"]
X = data.drop(['Unnamed: 0',"FIS_time",
 'FIS_Unnamed: 0',"FIS_close","FIS_momentum_kama"], axis=1)

# %%
# Lagging the Y by 1 time step
# Predicting one step ahead
Y= Y[31:]
X= X[30:-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=60)

# %%
X_train
# Out:
#           FIS_open    FIS_high     FIS_low  FIS_volume  FIS_volume_adi  \
# 32707   139.046350  139.066302  139.046350         980    2.864905e+06
# 39391   138.088648  138.128552  138.073684        2777    4.296869e+06
# 96562   136.517974  136.643152  136.517974        3540   -2.479966e+05
# 93926   133.856091  133.875882  133.856091         802    4.784376e+05
# 114051  130.076020  130.115602  130.076020        3494   -2.126385e+05
# ...            ...         ...         ...         ...             ...
# 65455    97.670351   97.749952   96.476337       18490    2.570511e+06
# 168038  105.233424  105.243233  105.218710       14487   -6.391158e+06
# 174209  106.008353  106.018162  106.008353         648   -5.964226e+06
# 6573    141.360000  141.360000  141.290000        1518    8.563560e+04
# 133355  125.309225  125.324030  125.309225        2011   -4.710246e+06
#
#         FIS_volume_obv  FIS_volume_cmf  FIS_volume_fi  FIS_momentum_mfi  \
# 32707          7079104        0.045018      19.930397         61.972367
# 39391         10119932        0.139777     -68.272121         49.336066
# 96562         41269563       -0.144179      22.167179         58.775317
# 93926         39634933        0.076937    -136.240221         23.508153
# 114051        49861815       -0.111896      48.869051         72.100898
# ...                ...             ...            ...               ...
# 65455         24470447       -0.474377    3339.145496         61.869055
# 168038        80505956        0.309823     -72.548079         20.500514
# 174209        83356326       -0.220642      -2.712505         46.511277
# 6573           2952996        0.352733      -9.724611         60.986809
# 133355        62002870        0.114173      -7.601778         39.922487
#
#         FIS_volume_em  ...  FIS_momentum_tsi  FIS_momentum_uo  \
# 32707      -81.242294  ...         20.118571        52.846206
# 39391      -68.987930  ...        -20.983267        45.915549
# 96562      -76.106162  ...          3.986535        48.194928
# 93926      -79.361940  ...        -20.265988        51.125237
# 114051      28.025308  ...         16.219320        48.262972
# ...               ...  ...               ...              ...
# 65455     6168.391991  ...         -1.924064        37.983751
# 168038       3.736061  ...          9.171178        56.513614
# 174209      33.410072  ...        -23.664192        39.746011
# 6573       253.623188  ...        -17.182850        48.750722
# 133355      -9.082120  ...         19.772367        52.108377
#
#         FIS_momentum_stoch  FIS_momentum_stoch_signal  FIS_momentum_wr  \
# 32707            50.000000                  71.052632       -50.000000
# 39391             3.225806                   9.511424       -96.774194
# 96562            74.600000                  64.200000       -25.400000
# 93926             6.451613                  15.053763       -93.548387
# 114051           95.238095                  76.190476        -4.761905
# ...                    ...                        ...              ...
# 65455            61.904762                  60.518895       -38.095238
# 168038           23.191095                  26.283241       -76.808905
# 174209           20.512821                  11.111111       -79.487179
# 6573             28.000000                  22.658152       -72.000000
# 133355           41.666666                  58.333333       -58.333334
#
#         FIS_momentum_ao  FIS_momentum_roc  FIS_others_dr  FIS_others_dlr  \
# 32707          0.088501          0.010762      -0.053775       -0.053789
# 39391         -0.204495         -0.288143      -0.043328       -0.043337
# 96562          0.017484          0.048181       0.033686        0.033680
# 93926         -0.186151         -0.132881      -0.033253       -0.033259
# 114051         0.112673          0.114216       0.038043        0.038036
# ...                 ...               ...            ...             ...
# 65455          0.519422          2.192243       0.607004        0.605169
# 168038         0.060428         -0.032616       0.004661        0.004661
# 174209        -0.175008         -0.267602       0.064809        0.064788
# 6573          -0.188774         -0.098989       0.028319        0.028315
# 133355         0.043412         -0.031491       0.000000        0.000000
#
#         FIS_others_cr
# 32707       -3.126915
# 39391       -3.804495
# 96562       -4.811458
# 93926       -6.746091
# 114051      -9.365583
# ...               ...
# 65455      -32.792520
# 168038     -26.695563
# 174209     -26.145481
# 6573        -1.574364
# 133355     -12.696601
#
# [116005 rows x 75 columns]

# %%
X_train = X_train.dropna(axis =1)

# %%
X_test = X_test.dropna(axis =1)

# %%
X_test
# Out:
#           FIS_open    FIS_high     FIS_low  FIS_volume  FIS_volume_adi  \
# 186289   98.376772   98.386581   98.376772         251   -7.549433e+06
# 36081   137.809318  137.849222  137.629749        6019    4.624519e+06
# 121553  136.693795  136.713534  136.683926       23129   -1.714392e+06
# 118621  134.334964  134.394181  134.325094        8746   -8.753953e+05
# 18037   145.720335  145.760239  145.610598        3444    1.491621e+06
# ...            ...         ...         ...         ...             ...
# 131736  127.840775  127.909862  127.840775        8496   -4.778814e+06
# 122383  136.960274  137.063905  136.960274        2521   -1.910244e+06
# 135633  123.310634  123.350112  123.300764        2880   -4.376036e+06
# 7698    141.960000  142.060000  141.930000       12744    4.621455e+05
# 45747   137.266842  137.311618  137.251917        3899    3.924498e+06
#
#         FIS_volume_obv  FIS_volume_cmf  FIS_volume_fi  FIS_momentum_mfi  \
# 186289        85137666       -0.184174      59.373408         58.896635
# 36081          8504166        0.059747     -26.992838         64.861291
# 121553        57481569       -0.246031      40.231420         64.849222
# 118621        55316656       -0.090432    -136.559228         46.884559
# 18037          4031966        0.288140    -320.158035         25.524957
# ...                ...             ...            ...               ...
# 131736        61589123        0.216223     -90.970236         70.765131
# 122383        58383656        0.197213      66.862919         40.232940
# 135633        62789074       -0.078159     -30.491514         69.520772
# 7698           2421008        0.457812    -505.899515         27.184740
# 45747         12514974       -0.119858      27.016106         54.110657
#
#         FIS_volume_vpt  ...  FIS_trend_psar_up_indicator  \
# 186289        3.303208  ...                          0.0
# 36081        -0.226643  ...                          1.0
# 121553        6.609802  ...                          0.0
# 118621        6.242294  ...                          0.0
# 18037        -2.680388  ...                          0.0
# ...                ...  ...                          ...
# 131736       -0.363769  ...                          0.0
# 122383       -2.811784  ...                          0.0
# 135633       -2.403890  ...                          0.0
# 7698        -26.998311  ...                          0.0
# 45747        -0.258749  ...                          0.0
#
#         FIS_trend_psar_down_indicator  FIS_momentum_rsi  FIS_momentum_stoch  \
# 186289                            0.0         72.665308           96.153846
# 36081                             0.0         47.588734           26.666667
# 121553                            0.0         50.215652           36.000001
# 118621                            0.0         45.098262           60.869565
# 18037                             0.0         20.854621            6.060606
# ...                               ...               ...                 ...
# 131736                            0.0         49.911308           82.827167
# 122383                            1.0         48.023169           50.000000
# 135633                            1.0         47.733488           31.250000
# 7698                              0.0         47.611144           60.000000
# 45747                             0.0         53.290033           70.000000
#
#         FIS_momentum_stoch_signal  FIS_momentum_wr  FIS_momentum_roc  \
# 186289                  89.837135        -3.846154          0.601805
# 36081                   35.482032       -73.333333          0.014499
# 121553                  20.000000       -63.999999         -0.007220
# 118621                  26.025285       -39.130435         -0.040392
# 18037                    4.577313       -93.939394         -0.734095
# ...                           ...              ...               ...
# 131736                  79.258441       -17.172833          0.077226
# 122383                  68.095238       -50.000000          0.043223
# 135633                  66.995614       -68.750000         -0.016006
# 7698                    65.714286       -40.000000          0.042254
# 45747                   74.024450       -30.000000          0.188761
#
#         FIS_others_dr  FIS_others_dlr  FIS_others_cr
# 186289       0.024931        0.024928     -31.461804
# 36081        0.000000        0.000000      -4.124173
# 121553       0.014443        0.014441      -4.776179
# 118621       0.088242        0.088203      -6.419391
# 18037       -0.088938       -0.088977       1.491053
# ...               ...             ...            ...
# 131736      -0.023145       -0.023147     -10.902130
# 122383      -0.010800       -0.010800      -4.518353
# 135633      -0.056000       -0.056016     -14.106051
# 7698         0.000000        0.000000      -1.037966
# 45747        0.000000        0.000000      -4.345790
#
# [77337 rows x 63 columns]

# %%
correlation_row = data.corr()[5:6]

# %%
high_corr_list = []
for i in range(len(list(correlation_row.T["FIS_close"]))):
    if list(correlation_row.T["FIS_close"])[i] > 0.5 or list(correlation_row.T["FIS_close"])[i] < -0.5:
        high_corr_list.append(list(correlation_row)[i])
        print (f'{list(correlation_row)[i]} has a correlation with closing price of {list(correlation_row.T["FIS_close"])[i]}')
# Out:
# Unnamed: 0 has a correlation with closing price of -0.8079018352221715
# FIS_open has a correlation with closing price of 0.9999694848218778
# FIS_high has a correlation with closing price of 0.9999797637275386
# FIS_low has a correlation with closing price of 0.999980251300908
# FIS_close has a correlation with closing price of 1.0
# FIS_volume_adi has a correlation with closing price of 0.7416213994219419
# FIS_volume_obv has a correlation with closing price of -0.8029516375725723
# FIS_volume_vwap has a correlation with closing price of 0.9998186686128865
# FIS_volatility_bbm has a correlation with closing price of 0.9997256900656188
# FIS_volatility_bbh has a correlation with closing price of 0.9993540798809664
# FIS_volatility_bbl has a correlation with closing price of 0.9992822659585274
# FIS_volatility_kcc has a correlation with closing price of 0.999870460058483
# FIS_volatility_kch has a correlation with closing price of 0.9998442649489658
# FIS_volatility_kcl has a correlation with closing price of 0.9998433477373432
# FIS_trend_sma_fast has a correlation with closing price of 0.9998350614780498
# FIS_trend_sma_slow has a correlation with closing price of 0.9996475989786382
# FIS_trend_ema_fast has a correlation with closing price of 0.9998830324827732
# FIS_trend_ema_slow has a correlation with closing price of 0.9997443643155517
# FIS_trend_ichimoku_conv has a correlation with closing price of 0.9998802350025287
# FIS_trend_ichimoku_base has a correlation with closing price of 0.99963075797481
# FIS_trend_ichimoku_a has a correlation with closing price of 0.999807377455128
# FIS_trend_ichimoku_b has a correlation with closing price of 0.9992820579459059
# FIS_trend_visual_ichimoku_a has a correlation with closing price of 0.9987339231093396
# FIS_trend_visual_ichimoku_b has a correlation with closing price of 0.9982582519603651
# FIS_trend_psar_up has a correlation with closing price of 0.9995713158824606
# FIS_trend_psar_down has a correlation with closing price of 0.9996825861328287
# FIS_momentum_kama has a correlation with closing price of 0.998106848306265
# FIS_others_cr has a correlation with closing price of 1.0000000000000486

# %%
high_corr_list
# Out:
# ['Unnamed: 0',
#  'FIS_open',
#  'FIS_high',
#  'FIS_low',
#  'FIS_close',
#  'FIS_volume_adi',
#  'FIS_volume_obv',
#  'FIS_volume_vwap',
#  'FIS_volatility_bbm',
#  'FIS_volatility_bbh',
#  'FIS_volatility_bbl',
#  'FIS_volatility_kcc',
#  'FIS_volatility_kch',
#  'FIS_volatility_kcl',
#  'FIS_trend_sma_fast',
#  'FIS_trend_sma_slow',
#  'FIS_trend_ema_fast',
#  'FIS_trend_ema_slow',
#  'FIS_trend_ichimoku_conv',
#  'FIS_trend_ichimoku_base',
#  'FIS_trend_ichimoku_a',
#  'FIS_trend_ichimoku_b',
#  'FIS_trend_visual_ichimoku_a',
#  'FIS_trend_visual_ichimoku_b',
#  'FIS_trend_psar_up',
#  'FIS_trend_psar_down',
#  'FIS_momentum_kama',
#  'FIS_others_cr']

# %%
# Drop Close 
high_corr_list.remove("FIS_close")
high_corr_list.remove('Unnamed: 0')

# %%
my_list = ['FIS_trend_psar_down', 'FIS_trend_visual_ichimoku_a', 'FIS_momentum_kama', 'FIS_trend_psar_up']
for i in my_list:
    high_corr_list.remove(i)

# %%
high_corr_list
# Out:
# ['FIS_open',
#  'FIS_high',
#  'FIS_low',
#  'FIS_volume_adi',
#  'FIS_volume_obv',
#  'FIS_volume_vwap',
#  'FIS_volatility_bbm',
#  'FIS_volatility_bbh',
#  'FIS_volatility_bbl',
#  'FIS_volatility_kcc',
#  'FIS_volatility_kch',
#  'FIS_volatility_kcl',
#  'FIS_trend_sma_fast',
#  'FIS_trend_sma_slow',
#  'FIS_trend_ema_fast',
#  'FIS_trend_ema_slow',
#  'FIS_trend_ichimoku_conv',
#  'FIS_trend_ichimoku_base',
#  'FIS_trend_ichimoku_a',
#  'FIS_trend_ichimoku_b',
#  'FIS_trend_visual_ichimoku_b',
#  'FIS_others_cr']

# %%
X_train3 = X_train[high_corr_list]
X_test3 = X_test[high_corr_list]

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(100,input_shape=(X_train3.shape[1],1)))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
X_train3 = np.array(X_train3).reshape((X_train3.shape[0],X_train3.shape[1],1))
X_test3 = np.array(X_test3).reshape((X_test3.shape[0],X_test3.shape[1],1))

# %%
history = model.fit(x=X_train3[:103606],y=Y_train[:103606],epochs=2,validation_data=(X_train3[103606:],Y_train[103606:]),shuffle=False)
# Out:
# Train on 103606 samples, validate on 12399 samples
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/2
# 103606/103606 [==============================] - 196s 2ms/sample - loss: 2346.3417 - val_loss: 21.9497
# Epoch 2/2
# 103606/103606 [==============================] - 243s 2ms/sample - loss: 4.0818 - val_loss: 0.5346

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 300

axes=plt.axes()
axes.plot(pd.DataFrame(model.history.history)['loss'], label='Loss')
axes.plot(pd.DataFrame(model.history.history)['val_loss'], label='Validation Loss')
axes.legend(loc=0)
axes.set_title('FIS Model fitting performance')
# Out:
# Text(0.5, 1.0, 'FIS Model fitting performance')

# %%
Y_predicted=model.predict(np.array(X_test3))
Y_true=np.array(Y_test).reshape(np.array(Y_test).shape[0],1)

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(Y_true[::100], label='True Y')
plt.plot(Y_predicted[::100], label='Predicted Y')
plt.legend(loc=0)
plt.title('FIS LSTM Prediction vs Actual')
plt.show()

# %%
from sklearn import metrics
Y_p=Y_predicted
Y_t=Y_true

print(f'The Model Accuracy (%) for FIS is {(1-(metrics.mean_absolute_error(Y_t, Y_p)/Y_t.mean()))*100}')

print('')
print('Prediction performance')
print(f'The MAE in % is {(metrics.mean_absolute_error(Y_true, Y_predicted)/Y_true.mean())*100}')
print(f'MSE: {metrics.mean_squared_error(Y_true, Y_predicted)}')
print(f'RMSE: {np.sqrt(metrics.mean_squared_error(Y_true, Y_predicted))}')
print(f'R2: {metrics.r2_score(Y_true, Y_predicted)}')
# Out:
# The Model Accuracy (%) for FIS is 99.823885721336
#
# Prediction performance
# The MAE in % is 0.17611427866399712
# MSE: 0.49684831822614917
# RMSE: 0.7048746826395095
# R2: 0.9977900178177191

# %%
# Calculating the profits from the model

actual_y = list(Y)
predicted_y1 = model.predict(np.array(X_train3))
predicted_y2 = model.predict(np.array(X_test3))

# %%
predicted_y = [predicted_y1[i][0] for i in range(len(predicted_y1))] + [predicted_y2[i][0] for i in range(len(predicted_y2))]

# %%
starting_value = 1000000
portfolio_value = [starting_value]

# %%
stock_amount = portfolio_value[-1]/actual_y[0]

# %%
holding_period = 1

# %%
# 2.75 bsp transaction fees

def calculate_returns(holding_period, predicted_y, actual_y):
    starting_value = 1000000
    portfolio_value = [starting_value]
    
    for i in range(0,len(actual_y)-holding_period,holding_period):
        if predicted_y[i+holding_period] > actual_y[i]:
            
            #Buying if predicted price in the next time step is higher
            stock_amount = (portfolio_value[-1]*(1-0.000275))/actual_y[i]
            
            #Selling taking into account the transaction fees
            new_portfolio_value = (stock_amount*actual_y[i+holding_period])*(1-0.000275)
            portfolio_value.append(new_portfolio_value)
            
        elif predicted_y[i+holding_period] < actual_y[i]:
            
            #Selling first then buying back
            new_value_after_short = (- portfolio_value[-1]/actual_y[i] + portfolio_value[-1]/actual_y[i]*actual_y[i+holding_period])*(1-0.000275)**2
            portfolio_value.append(new_value_after_short)
        else:
            portfolio_value.append(portfolio_value[-1])
    return portfolio_value

# %%
holding_period_1 = calculate_returns(1, predicted_y, actual_y)

# %%
holding_period_5 = calculate_returns(5, predicted_y, actual_y)

# %%
holding_period_10 = calculate_returns(10, predicted_y, actual_y)

# %%
holding_period_1000 = calculate_returns(1000, predicted_y, actual_y)

# %%
holding_period_5000 = calculate_returns(5000, predicted_y, actual_y)

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(holding_period_1[:100], color='red', label= "holding for 1 minutes")
plt.plot(holding_period_5[:100], color='green', label= "holding for 5 minutes")
plt.plot(holding_period_10[:100], color='blue', label= "holding for 10 minutes")
plt.plot(holding_period_1000[:100], color='orange', label= "holding for 1000 minutes")
plt.plot(holding_period_5000[:100], color='pink', label= "holding for 5000 minutes")
plt.ylabel("Portfolio Value")

# Both Long and Short
plt.legend(loc=0)
plt.title('High Frequency Trading with LSTM Predictions: Different Holding Periods (FIS)\n')
plt.show()

# %%
# 2.75 bsp transaction fees, only execute if predicted is 20% higher

def calculate_returns2(holding_period, predicted_y, actual_y):
    starting_value = 1000000
    portfolio_value = [starting_value]
    
    for i in range(0,len(actual_y)-holding_period,holding_period):
        if predicted_y[i+holding_period] > 1.20*actual_y[i]:
            
            #Buying if predicted price in the next time step is higher
            stock_amount = (portfolio_value[-1]*(1-0.000275))/actual_y[i]
            
            #Selling taking into account the transaction fees
            new_portfolio_value = (stock_amount*actual_y[i+holding_period])*(1-0.000275)
            portfolio_value.append(new_portfolio_value)
            
        elif 1.20*predicted_y[i+holding_period] < actual_y[i]:
            
            #Selling first then buying back
            new_value_after_short = (- portfolio_value[-1]/actual_y[i] + portfolio_value[-1]/actual_y[i]*actual_y[i+holding_period])*(1-0.000275)**2
            portfolio_value.append(new_value_after_short)
            
        else:
            portfolio_value.append(portfolio_value[-1])
    return portfolio_value

# %%
holding_period_1_2 = calculate_returns2(1, predicted_y, actual_y)
holding_period_5_2 = calculate_returns2(5, predicted_y, actual_y)
holding_period_10_2 = calculate_returns2(10, predicted_y, actual_y)
holding_period_1000_2 = calculate_returns2(1000, predicted_y, actual_y)
holding_period_5000_2 = calculate_returns2(5000, predicted_y, actual_y)

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(holding_period_1_2[:100], color='red', label= "holding for 1 minutes")
plt.plot(holding_period_5_2[:100], color='green', label= "holding for 5 minutes")
plt.plot(holding_period_10_2[:100], color='blue', label= "holding for 10 minutes")
plt.plot(holding_period_1000_2[:100], color='orange', label= "holding for 1000 minutes")
plt.plot(holding_period_5000_2[:100], color='pink', label= "holding for 5000 minutes")

# Both Long and Short
plt.legend(loc=0)
plt.title('High Frequency Trading with LSTM Predictions: Only trading if predicted price is 20% higher\n')
plt.show()

# The index is not aligned because 5000 min frequency has to fit in with 1 min frequency, so I graphed it like this so everything can fit in one
